# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Out:
# --2026-01-14 16:24:30--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Risoluzione di www.dropbox.com (www.dropbox.com)... 162.125.69.18
# connesso.ne a www.dropbox.com (www.dropbox.com)|162.125.69.18|:443...
# 302 Found HTTP inviata, in attesa di risposta...
# Posizione: https://www.dropbox.com/scl/fi/pkkpoxlm7beasryexpdf8/data_000637.txt?rlkey=rkm2em1v57hewglzelmin21c9 [segue]
# --2026-01-14 16:24:30--  https://www.dropbox.com/scl/fi/pkkpoxlm7beasryexpdf8/data_000637.txt?rlkey=rkm2em1v57hewglzelmin21c9
# Riutilizzo della connessione esistente a www.dropbox.com:443.
# 302 Found HTTP inviata, in attesa di risposta...
# Posizione: https://uc57249e420ff8e8ca778c2b7d14.dl.dropboxusercontent.com/cd/0/inline/C49ibGFxaorSNOqAJBwO99MAnhJzgymB6DnN-3WvJUQwpCKxNkq8fSG_Hs0Cviid-zIn64_mFqnghnv_fptpgywH7IJNkaFv9x_tTYWdVbFrQILHPs2_WeFDfZC-AlOSJa4/file# [segue]
# ...

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy.random as npr

# %%
### EX 1 ###
N = 120000
file = "data_000637.txt"
df = pd.read_csv(file) #, nrows=N)
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %%
### EX 2 ###

def custom_f(group):
    return pd.Series(
        {
            'Count': group['BX_COUNTER'].count(),
            'min': group['BX_COUNTER'].min(),
            'max': group['BX_COUNTER'].max(),
        }
    )

orbit_group = df.groupby('ORBIT_CNT').apply(custom_f)
print(orbit_group)

# BX_COUNTER is written when there are hits 
# This means that x is about the max value in BX_COUNTER (for each group)

# EQUIVALENTLY:
# orbit_group = df.groupby('ORBIT_CNT')['BX_COUNTER'].max()  –> gives only the max value

# Mean value of 'x':
x = orbit_group['max'].mean()
print('Mean value of x is: ', orbit_group['max'].mean())
# Out:
#             Count   min   max
# ORBIT_CNT
# 3869200167     43  2374  3187
# 3869200168     85     7  3538
# 3869200169    127     1  2766
# 3869200170     98   846  3377
# 3869200171    109   125  3542
# ...           ...   ...   ...
# 3869211167    208    46  3553
# 3869211168    109   215  3556
# 3869211169    191    44  3498
# 3869211170    137     6  3527
# 3869211171     22     9   769
#
# [11001 rows x 3 columns]
# Mean value of x is:  3280.1814380510864
# /var/folders/k_/4mk26lc17c1_f33q7r45t8f80000gn/T/ipykernel_3821/2861845576.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   orbit_group = df.groupby('ORBIT_CNT').apply(custom_f)

# %%
### EX 3 ###
print(f'Data taking lasted: {orbit_group['max'].sum()*25e-9} seconds')
print(f'Data taking lasted: {(df['ORBIT_CNT'].max() - df['ORBIT_CNT'].min()) * orbit_group['max'].mean()*25e-9} seconds')
# Out:
# Data taking lasted: 0.9021319 seconds
# Data taking lasted: 0.9023779136078538 seconds

# %%
### EX 4 ###
df['TIME'] = (df['ORBIT_CNT']*x + df['BX_COUNTER'])*25e-9 + df['TDC_MEAS']* ((25/30)*10**-9)
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#                   TIME
# 0        317291.964257
# 1        317291.964257
# 2        317291.964261
# 3        317291.964261
# 4        317291.964266
# ...

# %%
### EX 5 ###
df['HEAD'] = npr.randint(0,2, size=(len(df),1))
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           0     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           0     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     0     1            4  3869211171         763        11
# 1310717     0     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#                   TIME
# 0        317291.964257
# 1        317291.964257
# 2        317291.964261
# 3        317291.964261
# 4        317291.964266
# ...

# %%
### EX 6 ###
df2 = df[ df['HEAD'] == 1 ]
df2
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 4           1     0           64  3869200167        2760        25
# 7           1     0          139  3869200167        2776         0
# 8           1     0           62  3869200167        2774        21
# ...       ...   ...          ...         ...         ...       ...
# 1310709     1     1           38  3869211171         417         8
# 1310714     1     0           60  3869211171         762         2
# 1310715     1     0           62  3869211171         762        14
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#                   TIME
# 1        317291.964257
# 2        317291.964261
# 4        317291.964266
# 7        317291.964267
# 8        317291.964267
# ...

# %%
### EX 7 ###
occupacy0 = df2[ df2['FPGA'] == 0 ].groupby('TDC_CHANNEL').size()
occupacy1 = df2[ df2['FPGA'] == 1 ].groupby('TDC_CHANNEL').size()

occupacy0.plot()
# Out:
# <Axes: xlabel='TDC_CHANNEL'>

# %%
occupacy1.plot()
# Out:
# <Axes: xlabel='TDC_CHANNEL'>

# %%
### EX 8 ###
channels = df2.groupby('TDC_CHANNEL').size()
print(channels.nlargest(3))
# Out:
# TDC_CHANNEL
# 139    54080
# 64     32868
# 63     32454
# dtype: int64

# %%
### EX 9 ###
# Number of distinct orbits
print(f'Number of unique orbits is: {len(df['ORBIT_CNT'].unique())}')

# Number of unique orbits with at least 1 measurement from TDC_CHANNEL 139
uo139 = len(df[ df['TDC_CHANNEL'] == 139 ]['ORBIT_CNT'].unique())
print(f'Number of unique orbits with at least 1 measurement from TDC_CHANNEL 139 is: {uo139}')
# Out:
# Number of unique orbits is: 11001
# Number of unique orbits with at least 1 measurement from TDC_CHANNEL 139 is: 10976
